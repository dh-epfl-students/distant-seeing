# %% [markdown]
# # Setup

# %%
# !git clone https://github.com/haochen23/fine-tune-MaskRcnn.git
# !cp -r fine-tune-MaskRcnn/beagle/ ./beagle/

# %% [markdown]
# # Randomize Test/Eval + Generate json

# %%
def rnd_val_train():
    rnd = random.randrange(1,20)
    if rnd == 1:
        return True
    else:
        return False

# %%
import cv2
import os
import random
import shutil
import json
file = 'hand/json_hand_segmentation.json'
folder = 'hand/PNGImages1'
train_folder = 'hand/train'
val_folder = 'hand/val'
#Remove old img
for f in os.listdir(train_folder):
    os.remove(os.path.join(train_folder, f))
for f in os.listdir(val_folder):
    os.remove(os.path.join(val_folder, f))
#open old json
with open(file, 'r') as f:
  data2 = json.load(f)
#print(data2)
i = 0
#print(rnd)
json_global_train = {}
json_global_val = {}
for element in data2['samples']:
    #print(element['imageUrl'][45:])
    im = cv2.imread(os.path.join(folder, element['imageUrl'][45:]))
    val = rnd_val_train()
    if val:
        shutil.copyfile(os.path.join(folder, element['imageUrl'][45:]), os.path.join(val_folder, str(i)+".jpg"))
    else:
        shutil.copyfile(os.path.join(folder, element['imageUrl'][45:]), os.path.join(train_folder, str(i)+".jpg"))
    #print(im.shape[0])
    regions = []
    for shape in element['annotation']:
        all_points_x = []
        all_points_y = []
        for points in shape['points']:
            all_points_x.append(int(points['x']*im.shape[0]))
            all_points_y.append(int(points['y']*im.shape[1]))
        #print(element['imageUrl'][45:])
        #print((shape['classification']))
        json_el = {
            'shape_attributes':{
                'name': shape['regionType'],
                'all_points_x' : all_points_x,
                'all_points_y' : all_points_y
            },
            'region_attributes' : {
                'name' : shape['classification']
            }
        }
        regions.append(json_el)
    #print(f"{i:08d}")
    json_al = {
        'filename' : str(i)+".jpg",
        'size' : int(im.shape[0]*im.shape[1]),
        'regions' : regions,
        'file_attributes' : {} 
    }
    json_bl = {
        str(i)+".jpg"+str(int(im.shape[0]*im.shape[1])) : json_al
    }
    if val:
        json_global_val.update(json_bl)
    else:
        json_global_train.update(json_bl)
    i=i+1
        
json_val = json.dumps(json_global_val)
json_train = json.dumps(json_global_train)
with open("hand/val/via_region_data.json", "w") as outfile:
    outfile.write(json_val)
with open("hand/train/via_region_data.json", "w") as outfile:
    outfile.write(json_train)
print("done with dataset")
# Out:
# done with dataset

# %%
import os
import numpy as np
import torch
import torch.utils.data
from PIL import Image
import json


class BeagleDataset(torch.utils.data.Dataset):
    def __init__(self, data_dir, transforms=None):
        self.data_dir = data_dir
        self.transforms = transforms
        # load the annotations file, it also contain information of image names
        # load annotations
        annotations1 = json.load(open(os.path.join(data_dir, "via_region_data.json")))
        self.annotations = list(annotations1.values())  # don't need the dict keys
        

    def __getitem__(self, idx):

        # get the image path from the annoations data
        img_name = self.annotations[idx]["filename"]
        img_path = os.path.join(self.data_dir, img_name)
        img = Image.open(img_path).convert("RGB")
        
        # first id is the background, objects count from 1
        obj_ids = np.array(range(len(self.annotations[idx]["regions"]))) +1
        # get bounding box coordinates for each object
        num_objs = len(obj_ids)
        boxes = []
        #print(self.annotations[idx]["filename"])
        for i in range(num_objs):
            xmin = np.min(self.annotations[idx]["regions"][i]["shape_attributes"]["all_points_x"])
            xmax = np.max(self.annotations[idx]["regions"][i]["shape_attributes"]["all_points_x"])
            ymin = np.min(self.annotations[idx]["regions"][i]["shape_attributes"]["all_points_y"])
            ymax = np.max(self.annotations[idx]["regions"][i]["shape_attributes"]["all_points_y"])
            boxes.append([xmin, ymin, xmax, ymax])

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.annotations)

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
      
def build_model(num_classes):
    # load an instance segmentation model pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)

    # get the number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    return model

# %%
from engine import train_one_epoch, evaluate
import utils
import transforms as T

def get_transform(train):
    transforms = []
    # converts the image, a PIL image, into a PyTorch Tensor
    transforms.append(T.ToTensor())
    if train:
        # during training, randomly flip the training images
        # and ground-truth for data augmentation
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

# use our dataset and defined transformations
#dataset = BeagleDataset('beagle/train', get_transform(train=True))
#dataset_test = BeagleDataset('beagle/val', get_transform(train=False))
dataset = BeagleDataset('hand/train', get_transform(train=True))
dataset_test = BeagleDataset('hand/val', get_transform(train=False))
# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=2, shuffle=True, num_workers=10,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=10,
    collate_fn=utils.collate_fn)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
# our dataset has two classes only - background and beagle
num_classes = 2

# get the model using our helper function
model = build_model(num_classes)
# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# cuda

# %%
# number of epochs
num_epochs = 25
 
for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [ 0/60]  eta: 0:01:18  lr: 0.000090  loss: 1.4701 (1.4701)  loss_classifier: 0.8480 (0.8480)  loss_box_reg: 0.0019 (0.0019)  loss_objectness: 0.4995 (0.4995)  loss_rpn_box_reg: 0.1207 (0.1207)  time: 1.3093  data: 0.6519  max mem: 5386
# Epoch: [0]  [10/60]  eta: 0:00:31  lr: 0.000936  loss: 0.5584 (0.7221)  loss_classifier: 0.2275 (0.3449)  loss_box_reg: 0.0451 (0.0344)  loss_objectness: 0.1308 (0.2918)  loss_rpn_box_reg: 0.0195 (0.0510)  time: 0.6390  data: 0.0665  max mem: 5944
# Epoch: [0]  [20/60]  eta: 0:00:25  lr: 0.001783  loss: 0.3880 (0.5228)  loss_classifier: 0.0782 (0.2238)  loss_box_reg: 0.0385 (0.0393)  loss_objectness: 0.0611 (0.2034)  loss_rpn_box_reg: 0.0193 (0.0562)  time: 0.6098  data: 0.0056  max mem: 6498
# Epoch: [0]  [30/60]  eta: 0:00:18  lr: 0.002629  loss: 0.1616 (0.4136)  loss_classifier: 0.0473 (0.1735)  loss_box_reg: 0.0128 (0.0421)  loss_objectness: 0.0589 (0.1568)  loss_rpn_box_reg: 0.0105 (0.0413)  time: 0.6035  data: 0.0054  max mem: 6498
# Epoch: [0]  [40/60]  eta: 0:00:12  lr: 0.003476  loss: 0.1531 (0.3573)  loss_classifier: 0.0424 (0.1406)  loss_box_reg: 0.0100 (0.0361)  loss_objectness: 0.0589 (0.1418)  loss_rpn_box_reg: 0.0113 (0.0389)  time: 0.6491  data: 0.0078  max mem: 6498
# Epoch: [0]  [50/60]  eta: 0:00:06  lr: 0.004323  loss: 0.1458 (0.3174)  loss_classifier: 0.0433 (0.1229)  loss_box_reg: 0.0213 (0.0361)  loss_objectness: 0.0505 (0.1249)  loss_rpn_box_reg: 0.0135 (0.0335)  time: 0.6612  data: 0.0094  max mem: 6498
# Epoch: [0]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.1543 (0.2975)  loss_classifier: 0.0524 (0.1122)  loss_box_reg: 0.0360 (0.0357)  loss_objectness: 0.0458 (0.1170)  loss_rpn_box_reg: 0.0096 (0.0326)  time: 0.6094  data: 0.0106  max mem: 6498
# Epoch: [0] Total time: 0:00:38 (0.6376 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:02  model_time: 0.1034 (0.1034)  evaluator_time: 0.0025 (0.0025)  time: 0.6047  data: 0.4976  max mem: 6498
# Test:  [3/4]  eta: 0:00:00  model_time: 0.0966 (0.1040)  evaluator_time: 0.0018 (0.0022)  time: 0.2362  data: 0.1281  max mem: 6498
# Test: Total time: 0:00:01 (0.2561 s / it)
# Averaged stats: model_time: 0.0966 (0.1040)  evaluator_time: 0.0018 (0.0022)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.040
# Epoch: [1]  [ 0/60]  eta: 0:01:03  lr: 0.005000  loss: 0.2002 (0.2002)  loss_classifier: 0.0834 (0.0834)  loss_box_reg: 0.0825 (0.0825)  loss_objectness: 0.0265 (0.0265)  loss_rpn_box_reg: 0.0077 (0.0077)  time: 1.0506  data: 0.5271  max mem: 6498
# Epoch: [1]  [10/60]  eta: 0:00:34  lr: 0.005000  loss: 0.2173 (0.2060)  loss_classifier: 0.0834 (0.0781)  loss_box_reg: 0.0605 (0.0636)  loss_objectness: 0.0274 (0.0380)  loss_rpn_box_reg: 0.0076 (0.0262)  time: 0.6852  data: 0.0559  max mem: 6498
# Epoch: [1]  [20/60]  eta: 0:00:26  lr: 0.005000  loss: 0.1896 (0.2021)  loss_classifier: 0.0595 (0.0722)  loss_box_reg: 0.0342 (0.0516)  loss_objectness: 0.0308 (0.0453)  loss_rpn_box_reg: 0.0107 (0.0330)  time: 0.6332  data: 0.0079  max mem: 6498
# Epoch: [1]  [30/60]  eta: 0:00:19  lr: 0.005000  loss: 0.1680 (0.2109)  loss_classifier: 0.0584 (0.0721)  loss_box_reg: 0.0342 (0.0554)  loss_objectness: 0.0322 (0.0506)  loss_rpn_box_reg: 0.0152 (0.0329)  time: 0.6339  data: 0.0073  max mem: 6498
# Epoch: [1]  [40/60]  eta: 0:00:13  lr: 0.005000  loss: 0.1488 (0.1968)  loss_classifier: 0.0522 (0.0662)  loss_box_reg: 0.0308 (0.0481)  loss_objectness: 0.0384 (0.0498)  loss_rpn_box_reg: 0.0152 (0.0326)  time: 0.6744  data: 0.0092  max mem: 6498
# Epoch: [1]  [50/60]  eta: 0:00:06  lr: 0.005000  loss: 0.1488 (0.2023)  loss_classifier: 0.0472 (0.0666)  loss_box_reg: 0.0168 (0.0478)  loss_objectness: 0.0418 (0.0532)  loss_rpn_box_reg: 0.0198 (0.0348)  time: 0.6687  data: 0.0101  max mem: 6498
# Epoch: [1]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.1783 (0.1955)  loss_classifier: 0.0515 (0.0659)  loss_box_reg: 0.0438 (0.0481)  loss_objectness: 0.0318 (0.0501)  loss_rpn_box_reg: 0.0106 (0.0315)  time: 0.6409  data: 0.0101  max mem: 6498
# Epoch: [1] Total time: 0:00:39 (0.6591 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:02  model_time: 0.1152 (0.1152)  evaluator_time: 0.0021 (0.0021)  time: 0.6094  data: 0.4901  max mem: 6498
# Test:  [3/4]  eta: 0:00:00  model_time: 0.0997 (0.1115)  evaluator_time: 0.0021 (0.0023)  time: 0.2426  data: 0.1263  max mem: 6498
# Test: Total time: 0:00:01 (0.2653 s / it)
# Averaged stats: model_time: 0.0997 (0.1115)  evaluator_time: 0.0021 (0.0023)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [2]  [ 0/60]  eta: 0:01:40  lr: 0.005000  loss: 0.2993 (0.2993)  loss_classifier: 0.0613 (0.0613)  loss_box_reg: 0.0292 (0.0292)  loss_objectness: 0.1073 (0.1073)  loss_rpn_box_reg: 0.1015 (0.1015)  time: 1.6766  data: 0.9980  max mem: 6498
# Epoch: [2]  [10/60]  eta: 0:00:38  lr: 0.005000  loss: 0.2112 (0.2282)  loss_classifier: 0.0548 (0.0661)  loss_box_reg: 0.0440 (0.0620)  loss_objectness: 0.0323 (0.0659)  loss_rpn_box_reg: 0.0129 (0.0342)  time: 0.7693  data: 0.0999  max mem: 6498
# Epoch: [2]  [20/60]  eta: 0:00:29  lr: 0.005000  loss: 0.1909 (0.2118)  loss_classifier: 0.0558 (0.0652)  loss_box_reg: 0.0440 (0.0569)  loss_objectness: 0.0398 (0.0595)  loss_rpn_box_reg: 0.0129 (0.0301)  time: 0.6884  data: 0.0071  max mem: 6498
# Epoch: [2]  [30/60]  eta: 0:00:21  lr: 0.005000  loss: 0.1782 (0.1897)  loss_classifier: 0.0542 (0.0607)  loss_box_reg: 0.0455 (0.0525)  loss_objectness: 0.0384 (0.0499)  loss_rpn_box_reg: 0.0150 (0.0266)  time: 0.7010  data: 0.0079  max mem: 6504
# Epoch: [2]  [40/60]  eta: 0:00:14  lr: 0.005000  loss: 0.1397 (0.1888)  loss_classifier: 0.0457 (0.0588)  loss_box_reg: 0.0386 (0.0495)  loss_objectness: 0.0303 (0.0506)  loss_rpn_box_reg: 0.0167 (0.0299)  time: 0.6986  data: 0.0118  max mem: 6504
# Epoch: [2]  [50/60]  eta: 0:00:07  lr: 0.005000  loss: 0.1599 (0.1913)  loss_classifier: 0.0550 (0.0611)  loss_box_reg: 0.0290 (0.0503)  loss_objectness: 0.0354 (0.0499)  loss_rpn_box_reg: 0.0127 (0.0299)  time: 0.7173  data: 0.0119  max mem: 6504
# Epoch: [2]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.1526 (0.1855)  loss_classifier: 0.0599 (0.0608)  loss_box_reg: 0.0429 (0.0505)  loss_objectness: 0.0312 (0.0464)  loss_rpn_box_reg: 0.0104 (0.0278)  time: 0.7293  data: 0.0121  max mem: 6504
# Epoch: [2] Total time: 0:00:43 (0.7280 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:03  model_time: 0.1191 (0.1191)  evaluator_time: 0.0026 (0.0026)  time: 0.8086  data: 0.6843  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1049 (0.1148)  evaluator_time: 0.0026 (0.0023)  time: 0.2963  data: 0.1760  max mem: 6504
# Test: Total time: 0:00:01 (0.3281 s / it)
# Averaged stats: model_time: 0.1049 (0.1148)  evaluator_time: 0.0026 (0.0023)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.020
# Epoch: [3]  [ 0/60]  eta: 0:01:32  lr: 0.000500  loss: 0.1753 (0.1753)  loss_classifier: 0.0183 (0.0183)  loss_box_reg: 0.0004 (0.0004)  loss_objectness: 0.0616 (0.0616)  loss_rpn_box_reg: 0.0951 (0.0951)  time: 1.5444  data: 0.9285  max mem: 6504
# Epoch: [3]  [10/60]  eta: 0:00:37  lr: 0.000500  loss: 0.1322 (0.1459)  loss_classifier: 0.0321 (0.0439)  loss_box_reg: 0.0151 (0.0384)  loss_objectness: 0.0275 (0.0372)  loss_rpn_box_reg: 0.0143 (0.0265)  time: 0.7431  data: 0.0931  max mem: 6504
# Epoch: [3]  [20/60]  eta: 0:00:30  lr: 0.000500  loss: 0.1383 (0.1520)  loss_classifier: 0.0321 (0.0466)  loss_box_reg: 0.0231 (0.0397)  loss_objectness: 0.0255 (0.0315)  loss_rpn_box_reg: 0.0143 (0.0341)  time: 0.7167  data: 0.0081  max mem: 6504
# Epoch: [3]  [30/60]  eta: 0:00:22  lr: 0.000500  loss: 0.1537 (0.1468)  loss_classifier: 0.0552 (0.0482)  loss_box_reg: 0.0265 (0.0399)  loss_objectness: 0.0212 (0.0291)  loss_rpn_box_reg: 0.0126 (0.0296)  time: 0.7711  data: 0.0095  max mem: 6504
# Epoch: [3]  [40/60]  eta: 0:00:14  lr: 0.000500  loss: 0.1537 (0.1584)  loss_classifier: 0.0603 (0.0563)  loss_box_reg: 0.0421 (0.0473)  loss_objectness: 0.0212 (0.0284)  loss_rpn_box_reg: 0.0094 (0.0264)  time: 0.7002  data: 0.0115  max mem: 6504
# Epoch: [3]  [50/60]  eta: 0:00:07  lr: 0.000500  loss: 0.1598 (0.1637)  loss_classifier: 0.0590 (0.0580)  loss_box_reg: 0.0522 (0.0510)  loss_objectness: 0.0216 (0.0291)  loss_rpn_box_reg: 0.0143 (0.0256)  time: 0.6793  data: 0.0110  max mem: 6504
# Epoch: [3]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1598 (0.1638)  loss_classifier: 0.0571 (0.0591)  loss_box_reg: 0.0522 (0.0536)  loss_objectness: 0.0210 (0.0276)  loss_rpn_box_reg: 0.0135 (0.0235)  time: 0.6914  data: 0.0103  max mem: 6504
# Epoch: [3] Total time: 0:00:43 (0.7209 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:02  model_time: 0.1285 (0.1285)  evaluator_time: 0.0079 (0.0079)  time: 0.7439  data: 0.6047  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1107 (0.1213)  evaluator_time: 0.0078 (0.0066)  time: 0.2898  data: 0.1581  max mem: 6504
# Test: Total time: 0:00:01 (0.3833 s / it)
# Averaged stats: model_time: 0.1107 (0.1213)  evaluator_time: 0.0078 (0.0066)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.040
# Epoch: [4]  [ 0/60]  eta: 0:02:00  lr: 0.000500  loss: 0.1772 (0.1772)  loss_classifier: 0.0742 (0.0742)  loss_box_reg: 0.0688 (0.0688)  loss_objectness: 0.0227 (0.0227)  loss_rpn_box_reg: 0.0115 (0.0115)  time: 2.0069  data: 1.4452  max mem: 6504
# Epoch: [4]  [10/60]  eta: 0:00:39  lr: 0.000500  loss: 0.1502 (0.1614)  loss_classifier: 0.0421 (0.0535)  loss_box_reg: 0.0485 (0.0507)  loss_objectness: 0.0227 (0.0255)  loss_rpn_box_reg: 0.0138 (0.0316)  time: 0.7928  data: 0.1477  max mem: 6504
# Epoch: [4]  [20/60]  eta: 0:00:28  lr: 0.000500  loss: 0.1502 (0.1874)  loss_classifier: 0.0517 (0.0651)  loss_box_reg: 0.0485 (0.0691)  loss_objectness: 0.0223 (0.0257)  loss_rpn_box_reg: 0.0138 (0.0275)  time: 0.6362  data: 0.0108  max mem: 6504
# Epoch: [4]  [30/60]  eta: 0:00:21  lr: 0.000500  loss: 0.1570 (0.1776)  loss_classifier: 0.0517 (0.0613)  loss_box_reg: 0.0457 (0.0605)  loss_objectness: 0.0264 (0.0277)  loss_rpn_box_reg: 0.0162 (0.0280)  time: 0.6868  data: 0.0090  max mem: 6504
# Epoch: [4]  [40/60]  eta: 0:00:14  lr: 0.000500  loss: 0.1280 (0.1662)  loss_classifier: 0.0479 (0.0582)  loss_box_reg: 0.0457 (0.0565)  loss_objectness: 0.0209 (0.0271)  loss_rpn_box_reg: 0.0111 (0.0243)  time: 0.7292  data: 0.0138  max mem: 6504
# Epoch: [4]  [50/60]  eta: 0:00:07  lr: 0.000500  loss: 0.1280 (0.1604)  loss_classifier: 0.0479 (0.0575)  loss_box_reg: 0.0470 (0.0542)  loss_objectness: 0.0217 (0.0268)  loss_rpn_box_reg: 0.0094 (0.0219)  time: 0.7009  data: 0.0124  max mem: 6504
# Epoch: [4]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1424 (0.1612)  loss_classifier: 0.0534 (0.0580)  loss_box_reg: 0.0470 (0.0567)  loss_objectness: 0.0222 (0.0260)  loss_rpn_box_reg: 0.0105 (0.0205)  time: 0.6708  data: 0.0119  max mem: 6504
# Epoch: [4] Total time: 0:00:42 (0.7062 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:05  model_time: 0.1288 (0.1288)  evaluator_time: 0.0064 (0.0064)  time: 1.2935  data: 1.1558  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1108 (0.1211)  evaluator_time: 0.0064 (0.0056)  time: 0.4281  data: 0.2968  max mem: 6504
# Test: Total time: 0:00:01 (0.4828 s / it)
# Averaged stats: model_time: 0.1108 (0.1211)  evaluator_time: 0.0064 (0.0056)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.040
# Epoch: [5]  [ 0/60]  eta: 0:01:13  lr: 0.000500  loss: 0.3901 (0.3901)  loss_classifier: 0.1450 (0.1450)  loss_box_reg: 0.2005 (0.2005)  loss_objectness: 0.0296 (0.0296)  loss_rpn_box_reg: 0.0151 (0.0151)  time: 1.2313  data: 0.6412  max mem: 6504
# Epoch: [5]  [10/60]  eta: 0:00:36  lr: 0.000500  loss: 0.1441 (0.1583)  loss_classifier: 0.0611 (0.0582)  loss_box_reg: 0.0443 (0.0655)  loss_objectness: 0.0203 (0.0230)  loss_rpn_box_reg: 0.0060 (0.0116)  time: 0.7318  data: 0.0697  max mem: 6504
# Epoch: [5]  [20/60]  eta: 0:00:29  lr: 0.000500  loss: 0.1441 (0.1567)  loss_classifier: 0.0465 (0.0548)  loss_box_reg: 0.0476 (0.0611)  loss_objectness: 0.0174 (0.0238)  loss_rpn_box_reg: 0.0068 (0.0170)  time: 0.7058  data: 0.0086  max mem: 6504
# Epoch: [5]  [30/60]  eta: 0:00:21  lr: 0.000500  loss: 0.1541 (0.1640)  loss_classifier: 0.0526 (0.0584)  loss_box_reg: 0.0660 (0.0662)  loss_objectness: 0.0232 (0.0238)  loss_rpn_box_reg: 0.0096 (0.0156)  time: 0.7190  data: 0.0102  max mem: 6504
# Epoch: [5]  [40/60]  eta: 0:00:14  lr: 0.000500  loss: 0.1730 (0.1703)  loss_classifier: 0.0612 (0.0620)  loss_box_reg: 0.0680 (0.0654)  loss_objectness: 0.0255 (0.0260)  loss_rpn_box_reg: 0.0124 (0.0170)  time: 0.7387  data: 0.0133  max mem: 6504
# Epoch: [5]  [50/60]  eta: 0:00:07  lr: 0.000500  loss: 0.1832 (0.1732)  loss_classifier: 0.0653 (0.0617)  loss_box_reg: 0.0561 (0.0651)  loss_objectness: 0.0250 (0.0253)  loss_rpn_box_reg: 0.0166 (0.0211)  time: 0.7111  data: 0.0114  max mem: 6504
# Epoch: [5]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1478 (0.1689)  loss_classifier: 0.0452 (0.0586)  loss_box_reg: 0.0269 (0.0590)  loss_objectness: 0.0213 (0.0263)  loss_rpn_box_reg: 0.0180 (0.0250)  time: 0.7250  data: 0.0112  max mem: 6504
# Epoch: [5] Total time: 0:00:44 (0.7378 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:06  model_time: 0.1377 (0.1377)  evaluator_time: 0.0079 (0.0079)  time: 1.6739  data: 1.5253  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1227 (0.1297)  evaluator_time: 0.0077 (0.0070)  time: 0.5313  data: 0.3887  max mem: 6504
# Test: Total time: 0:00:02 (0.6150 s / it)
# Averaged stats: model_time: 0.1227 (0.1297)  evaluator_time: 0.0077 (0.0070)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.020
# Epoch: [6]  [ 0/60]  eta: 0:02:13  lr: 0.000050  loss: 0.1066 (0.1066)  loss_classifier: 0.0362 (0.0362)  loss_box_reg: 0.0281 (0.0281)  loss_objectness: 0.0236 (0.0236)  loss_rpn_box_reg: 0.0187 (0.0187)  time: 2.2191  data: 1.4546  max mem: 6504
# Epoch: [6]  [10/60]  eta: 0:00:41  lr: 0.000050  loss: 0.1504 (0.1565)  loss_classifier: 0.0540 (0.0577)  loss_box_reg: 0.0569 (0.0570)  loss_objectness: 0.0235 (0.0240)  loss_rpn_box_reg: 0.0082 (0.0178)  time: 0.8208  data: 0.1435  max mem: 6504
# Epoch: [6]  [20/60]  eta: 0:00:29  lr: 0.000050  loss: 0.1579 (0.1531)  loss_classifier: 0.0540 (0.0549)  loss_box_reg: 0.0543 (0.0539)  loss_objectness: 0.0230 (0.0234)  loss_rpn_box_reg: 0.0085 (0.0209)  time: 0.6657  data: 0.0102  max mem: 6504
# Epoch: [6]  [30/60]  eta: 0:00:21  lr: 0.000050  loss: 0.1418 (0.1501)  loss_classifier: 0.0377 (0.0525)  loss_box_reg: 0.0363 (0.0520)  loss_objectness: 0.0226 (0.0234)  loss_rpn_box_reg: 0.0156 (0.0222)  time: 0.6598  data: 0.0085  max mem: 6504
# Epoch: [6]  [40/60]  eta: 0:00:13  lr: 0.000050  loss: 0.1722 (0.1629)  loss_classifier: 0.0612 (0.0582)  loss_box_reg: 0.0624 (0.0616)  loss_objectness: 0.0187 (0.0233)  loss_rpn_box_reg: 0.0167 (0.0198)  time: 0.6458  data: 0.0092  max mem: 6504
# Epoch: [6]  [50/60]  eta: 0:00:06  lr: 0.000050  loss: 0.1815 (0.1648)  loss_classifier: 0.0647 (0.0582)  loss_box_reg: 0.0754 (0.0610)  loss_objectness: 0.0207 (0.0241)  loss_rpn_box_reg: 0.0096 (0.0215)  time: 0.6483  data: 0.0099  max mem: 6504
# Epoch: [6]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1715 (0.1635)  loss_classifier: 0.0509 (0.0577)  loss_box_reg: 0.0585 (0.0613)  loss_objectness: 0.0224 (0.0244)  loss_rpn_box_reg: 0.0103 (0.0201)  time: 0.7142  data: 0.0111  max mem: 6504
# Epoch: [6] Total time: 0:00:42 (0.7063 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:03  model_time: 0.1236 (0.1236)  evaluator_time: 0.0066 (0.0066)  time: 0.8519  data: 0.7199  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1114 (0.1222)  evaluator_time: 0.0066 (0.0060)  time: 0.3171  data: 0.1857  max mem: 6504
# Test: Total time: 0:00:01 (0.3521 s / it)
# Averaged stats: model_time: 0.1114 (0.1222)  evaluator_time: 0.0066 (0.0060)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [7]  [ 0/60]  eta: 0:01:50  lr: 0.000050  loss: 0.1717 (0.1717)  loss_classifier: 0.0631 (0.0631)  loss_box_reg: 0.0521 (0.0521)  loss_objectness: 0.0340 (0.0340)  loss_rpn_box_reg: 0.0225 (0.0225)  time: 1.8362  data: 1.1850  max mem: 6504
# Epoch: [7]  [10/60]  eta: 0:00:42  lr: 0.000050  loss: 0.1592 (0.1668)  loss_classifier: 0.0647 (0.0652)  loss_box_reg: 0.0500 (0.0529)  loss_objectness: 0.0245 (0.0323)  loss_rpn_box_reg: 0.0148 (0.0163)  time: 0.8417  data: 0.1229  max mem: 6504
# Epoch: [7]  [20/60]  eta: 0:00:31  lr: 0.000050  loss: 0.1518 (0.1638)  loss_classifier: 0.0551 (0.0618)  loss_box_reg: 0.0492 (0.0552)  loss_objectness: 0.0211 (0.0275)  loss_rpn_box_reg: 0.0112 (0.0192)  time: 0.7396  data: 0.0115  max mem: 6504
# Epoch: [7]  [30/60]  eta: 0:00:23  lr: 0.000050  loss: 0.1463 (0.1569)  loss_classifier: 0.0522 (0.0589)  loss_box_reg: 0.0492 (0.0556)  loss_objectness: 0.0211 (0.0249)  loss_rpn_box_reg: 0.0094 (0.0176)  time: 0.7732  data: 0.0104  max mem: 6504
# Epoch: [7]  [40/60]  eta: 0:00:14  lr: 0.000050  loss: 0.1327 (0.1659)  loss_classifier: 0.0515 (0.0604)  loss_box_reg: 0.0452 (0.0609)  loss_objectness: 0.0211 (0.0251)  loss_rpn_box_reg: 0.0095 (0.0196)  time: 0.6888  data: 0.0128  max mem: 6504
# Epoch: [7]  [50/60]  eta: 0:00:07  lr: 0.000050  loss: 0.1230 (0.1580)  loss_classifier: 0.0415 (0.0572)  loss_box_reg: 0.0372 (0.0582)  loss_objectness: 0.0208 (0.0244)  loss_rpn_box_reg: 0.0095 (0.0183)  time: 0.6312  data: 0.0121  max mem: 6504
# Epoch: [7]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1317 (0.1606)  loss_classifier: 0.0446 (0.0567)  loss_box_reg: 0.0449 (0.0589)  loss_objectness: 0.0179 (0.0247)  loss_rpn_box_reg: 0.0100 (0.0203)  time: 0.7040  data: 0.0127  max mem: 6504
# Epoch: [7] Total time: 0:00:44 (0.7336 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:04  model_time: 0.1227 (0.1227)  evaluator_time: 0.0062 (0.0062)  time: 1.1864  data: 1.0559  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1090 (0.1198)  evaluator_time: 0.0062 (0.0055)  time: 0.3974  data: 0.2691  max mem: 6504
# Test: Total time: 0:00:01 (0.4279 s / it)
# Averaged stats: model_time: 0.1090 (0.1198)  evaluator_time: 0.0062 (0.0055)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [8]  [ 0/60]  eta: 0:01:42  lr: 0.000050  loss: 0.2894 (0.2894)  loss_classifier: 0.1086 (0.1086)  loss_box_reg: 0.1587 (0.1587)  loss_objectness: 0.0194 (0.0194)  loss_rpn_box_reg: 0.0027 (0.0027)  time: 1.7076  data: 1.2015  max mem: 6504
# Epoch: [8]  [10/60]  eta: 0:00:39  lr: 0.000050  loss: 0.1622 (0.1823)  loss_classifier: 0.0626 (0.0668)  loss_box_reg: 0.0694 (0.0777)  loss_objectness: 0.0194 (0.0224)  loss_rpn_box_reg: 0.0069 (0.0154)  time: 0.7825  data: 0.1224  max mem: 6504
# Epoch: [8]  [20/60]  eta: 0:00:29  lr: 0.000050  loss: 0.1434 (0.1725)  loss_classifier: 0.0525 (0.0581)  loss_box_reg: 0.0541 (0.0670)  loss_objectness: 0.0210 (0.0253)  loss_rpn_box_reg: 0.0069 (0.0220)  time: 0.6988  data: 0.0100  max mem: 6504
# Epoch: [8]  [30/60]  eta: 0:00:22  lr: 0.000050  loss: 0.1510 (0.1696)  loss_classifier: 0.0528 (0.0582)  loss_box_reg: 0.0622 (0.0653)  loss_objectness: 0.0231 (0.0247)  loss_rpn_box_reg: 0.0105 (0.0215)  time: 0.7157  data: 0.0101  max mem: 6504
# Epoch: [8]  [40/60]  eta: 0:00:15  lr: 0.000050  loss: 0.1803 (0.1728)  loss_classifier: 0.0578 (0.0593)  loss_box_reg: 0.0505 (0.0644)  loss_objectness: 0.0203 (0.0273)  loss_rpn_box_reg: 0.0191 (0.0218)  time: 0.7635  data: 0.0131  max mem: 6504
# Epoch: [8]  [50/60]  eta: 0:00:07  lr: 0.000050  loss: 0.1479 (0.1712)  loss_classifier: 0.0498 (0.0587)  loss_box_reg: 0.0462 (0.0632)  loss_objectness: 0.0192 (0.0265)  loss_rpn_box_reg: 0.0108 (0.0229)  time: 0.7814  data: 0.0123  max mem: 6504
# Epoch: [8]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1257 (0.1651)  loss_classifier: 0.0449 (0.0570)  loss_box_reg: 0.0419 (0.0597)  loss_objectness: 0.0211 (0.0262)  loss_rpn_box_reg: 0.0108 (0.0221)  time: 0.7849  data: 0.0144  max mem: 6504
# Epoch: [8] Total time: 0:00:46 (0.7711 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:03  model_time: 0.1224 (0.1224)  evaluator_time: 0.0062 (0.0062)  time: 0.9616  data: 0.8314  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1072 (0.1170)  evaluator_time: 0.0062 (0.0054)  time: 0.3388  data: 0.2134  max mem: 6504
# Test: Total time: 0:00:01 (0.3695 s / it)
# Averaged stats: model_time: 0.1072 (0.1170)  evaluator_time: 0.0062 (0.0054)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.040
# Epoch: [9]  [ 0/60]  eta: 0:01:45  lr: 0.000005  loss: 0.2530 (0.2530)  loss_classifier: 0.1071 (0.1071)  loss_box_reg: 0.1126 (0.1126)  loss_objectness: 0.0227 (0.0227)  loss_rpn_box_reg: 0.0106 (0.0106)  time: 1.7625  data: 1.1512  max mem: 6504
# Epoch: [9]  [10/60]  eta: 0:00:41  lr: 0.000005  loss: 0.1408 (0.1835)  loss_classifier: 0.0452 (0.0652)  loss_box_reg: 0.0421 (0.0656)  loss_objectness: 0.0281 (0.0297)  loss_rpn_box_reg: 0.0136 (0.0229)  time: 0.8218  data: 0.1192  max mem: 6504
# Epoch: [9]  [20/60]  eta: 0:00:30  lr: 0.000005  loss: 0.1328 (0.1636)  loss_classifier: 0.0447 (0.0572)  loss_box_reg: 0.0408 (0.0586)  loss_objectness: 0.0219 (0.0265)  loss_rpn_box_reg: 0.0102 (0.0213)  time: 0.7118  data: 0.0128  max mem: 6504
# Epoch: [9]  [30/60]  eta: 0:00:22  lr: 0.000005  loss: 0.1283 (0.1741)  loss_classifier: 0.0463 (0.0609)  loss_box_reg: 0.0522 (0.0679)  loss_objectness: 0.0195 (0.0249)  loss_rpn_box_reg: 0.0100 (0.0204)  time: 0.6864  data: 0.0105  max mem: 6504
# Epoch: [9]  [40/60]  eta: 0:00:14  lr: 0.000005  loss: 0.1508 (0.1725)  loss_classifier: 0.0513 (0.0616)  loss_box_reg: 0.0591 (0.0693)  loss_objectness: 0.0179 (0.0238)  loss_rpn_box_reg: 0.0084 (0.0178)  time: 0.6571  data: 0.0118  max mem: 6504
# Epoch: [9]  [50/60]  eta: 0:00:07  lr: 0.000005  loss: 0.1402 (0.1671)  loss_classifier: 0.0523 (0.0595)  loss_box_reg: 0.0591 (0.0645)  loss_objectness: 0.0170 (0.0234)  loss_rpn_box_reg: 0.0086 (0.0197)  time: 0.6951  data: 0.0116  max mem: 6504
# Epoch: [9]  [59/60]  eta: 0:00:00  lr: 0.000005  loss: 0.1291 (0.1640)  loss_classifier: 0.0438 (0.0578)  loss_box_reg: 0.0367 (0.0606)  loss_objectness: 0.0219 (0.0236)  loss_rpn_box_reg: 0.0127 (0.0219)  time: 0.7580  data: 0.0112  max mem: 6504
# Epoch: [9] Total time: 0:00:43 (0.7305 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:05  model_time: 0.1252 (0.1252)  evaluator_time: 0.0064 (0.0064)  time: 1.2767  data: 1.1431  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1070 (0.1200)  evaluator_time: 0.0064 (0.0056)  time: 0.4208  data: 0.2915  max mem: 6504
# Test: Total time: 0:00:01 (0.4563 s / it)
# Averaged stats: model_time: 0.1070 (0.1200)  evaluator_time: 0.0064 (0.0056)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [10]  [ 0/60]  eta: 0:01:52  lr: 0.000005  loss: 0.2417 (0.2417)  loss_classifier: 0.0971 (0.0971)  loss_box_reg: 0.1165 (0.1165)  loss_objectness: 0.0215 (0.0215)  loss_rpn_box_reg: 0.0066 (0.0066)  time: 1.8721  data: 1.2331  max mem: 6504
# Epoch: [10]  [10/60]  eta: 0:00:40  lr: 0.000005  loss: 0.2078 (0.2011)  loss_classifier: 0.0598 (0.0651)  loss_box_reg: 0.0447 (0.0797)  loss_objectness: 0.0265 (0.0299)  loss_rpn_box_reg: 0.0112 (0.0265)  time: 0.8168  data: 0.1248  max mem: 6504
# Epoch: [10]  [20/60]  eta: 0:00:30  lr: 0.000005  loss: 0.2078 (0.1872)  loss_classifier: 0.0646 (0.0661)  loss_box_reg: 0.0447 (0.0759)  loss_objectness: 0.0236 (0.0269)  loss_rpn_box_reg: 0.0095 (0.0184)  time: 0.6991  data: 0.0103  max mem: 6504
# Epoch: [10]  [30/60]  eta: 0:00:21  lr: 0.000005  loss: 0.1336 (0.1679)  loss_classifier: 0.0522 (0.0602)  loss_box_reg: 0.0465 (0.0657)  loss_objectness: 0.0212 (0.0262)  loss_rpn_box_reg: 0.0072 (0.0158)  time: 0.6693  data: 0.0079  max mem: 6504
# Epoch: [10]  [40/60]  eta: 0:00:14  lr: 0.000005  loss: 0.1186 (0.1673)  loss_classifier: 0.0406 (0.0584)  loss_box_reg: 0.0459 (0.0637)  loss_objectness: 0.0212 (0.0254)  loss_rpn_box_reg: 0.0104 (0.0198)  time: 0.6999  data: 0.0092  max mem: 6504
# Epoch: [10]  [50/60]  eta: 0:00:07  lr: 0.000005  loss: 0.1444 (0.1672)  loss_classifier: 0.0437 (0.0585)  loss_box_reg: 0.0516 (0.0648)  loss_objectness: 0.0164 (0.0248)  loss_rpn_box_reg: 0.0099 (0.0191)  time: 0.7244  data: 0.0099  max mem: 6504
# Epoch: [10]  [59/60]  eta: 0:00:00  lr: 0.000005  loss: 0.1492 (0.1632)  loss_classifier: 0.0468 (0.0578)  loss_box_reg: 0.0489 (0.0620)  loss_objectness: 0.0195 (0.0245)  loss_rpn_box_reg: 0.0099 (0.0189)  time: 0.7118  data: 0.0093  max mem: 6504
# Epoch: [10] Total time: 0:00:43 (0.7205 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:02  model_time: 0.1191 (0.1191)  evaluator_time: 0.0034 (0.0034)  time: 0.7228  data: 0.5985  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1041 (0.1145)  evaluator_time: 0.0034 (0.0030)  time: 0.2735  data: 0.1535  max mem: 6504
# Test: Total time: 0:00:01 (0.3063 s / it)
# Averaged stats: model_time: 0.1041 (0.1145)  evaluator_time: 0.0034 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [11]  [ 0/60]  eta: 0:01:30  lr: 0.000005  loss: 0.2113 (0.2113)  loss_classifier: 0.0831 (0.0831)  loss_box_reg: 0.1179 (0.1179)  loss_objectness: 0.0072 (0.0072)  loss_rpn_box_reg: 0.0031 (0.0031)  time: 1.5097  data: 1.0256  max mem: 6504
# Epoch: [11]  [10/60]  eta: 0:00:40  lr: 0.000005  loss: 0.1311 (0.1486)  loss_classifier: 0.0463 (0.0469)  loss_box_reg: 0.0366 (0.0401)  loss_objectness: 0.0215 (0.0265)  loss_rpn_box_reg: 0.0142 (0.0352)  time: 0.8039  data: 0.0983  max mem: 6504
# Epoch: [11]  [20/60]  eta: 0:00:31  lr: 0.000005  loss: 0.1399 (0.1653)  loss_classifier: 0.0463 (0.0544)  loss_box_reg: 0.0366 (0.0514)  loss_objectness: 0.0243 (0.0270)  loss_rpn_box_reg: 0.0142 (0.0325)  time: 0.7440  data: 0.0054  max mem: 6504
# Epoch: [11]  [30/60]  eta: 0:00:22  lr: 0.000005  loss: 0.1650 (0.1658)  loss_classifier: 0.0568 (0.0572)  loss_box_reg: 0.0689 (0.0578)  loss_objectness: 0.0206 (0.0244)  loss_rpn_box_reg: 0.0103 (0.0264)  time: 0.7103  data: 0.0066  max mem: 6504
# Epoch: [11]  [40/60]  eta: 0:00:14  lr: 0.000005  loss: 0.1464 (0.1661)  loss_classifier: 0.0559 (0.0573)  loss_box_reg: 0.0719 (0.0603)  loss_objectness: 0.0188 (0.0246)  loss_rpn_box_reg: 0.0103 (0.0239)  time: 0.6910  data: 0.0074  max mem: 6504
# Epoch: [11]  [50/60]  eta: 0:00:07  lr: 0.000005  loss: 0.1474 (0.1654)  loss_classifier: 0.0567 (0.0584)  loss_box_reg: 0.0608 (0.0621)  loss_objectness: 0.0195 (0.0236)  loss_rpn_box_reg: 0.0087 (0.0214)  time: 0.6622  data: 0.0071  max mem: 6504
# Epoch: [11]  [59/60]  eta: 0:00:00  lr: 0.000005  loss: 0.1474 (0.1651)  loss_classifier: 0.0498 (0.0576)  loss_box_reg: 0.0470 (0.0605)  loss_objectness: 0.0222 (0.0243)  loss_rpn_box_reg: 0.0106 (0.0227)  time: 0.6831  data: 0.0072  max mem: 6504
# Epoch: [11] Total time: 0:00:43 (0.7179 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:02  model_time: 0.1139 (0.1139)  evaluator_time: 0.0033 (0.0033)  time: 0.6763  data: 0.5578  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1038 (0.1128)  evaluator_time: 0.0032 (0.0027)  time: 0.2613  data: 0.1435  max mem: 6504
# Test: Total time: 0:00:01 (0.2896 s / it)
# Averaged stats: model_time: 0.1038 (0.1128)  evaluator_time: 0.0032 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [12]  [ 0/60]  eta: 0:01:10  lr: 0.000001  loss: 0.1293 (0.1293)  loss_classifier: 0.0323 (0.0323)  loss_box_reg: 0.0427 (0.0427)  loss_objectness: 0.0239 (0.0239)  loss_rpn_box_reg: 0.0304 (0.0304)  time: 1.1738  data: 0.5411  max mem: 6504
# Epoch: [12]  [10/60]  eta: 0:00:35  lr: 0.000001  loss: 0.1655 (0.1857)  loss_classifier: 0.0517 (0.0687)  loss_box_reg: 0.0490 (0.0727)  loss_objectness: 0.0226 (0.0269)  loss_rpn_box_reg: 0.0092 (0.0175)  time: 0.7114  data: 0.0584  max mem: 6504
# Epoch: [12]  [20/60]  eta: 0:00:27  lr: 0.000001  loss: 0.1655 (0.1691)  loss_classifier: 0.0517 (0.0620)  loss_box_reg: 0.0505 (0.0625)  loss_objectness: 0.0211 (0.0251)  loss_rpn_box_reg: 0.0100 (0.0195)  time: 0.6556  data: 0.0063  max mem: 6504
# Epoch: [12]  [30/60]  eta: 0:00:19  lr: 0.000001  loss: 0.1613 (0.1777)  loss_classifier: 0.0569 (0.0626)  loss_box_reg: 0.0551 (0.0634)  loss_objectness: 0.0235 (0.0261)  loss_rpn_box_reg: 0.0112 (0.0256)  time: 0.6381  data: 0.0050  max mem: 6504
# Epoch: [12]  [40/60]  eta: 0:00:13  lr: 0.000001  loss: 0.1289 (0.1661)  loss_classifier: 0.0442 (0.0587)  loss_box_reg: 0.0551 (0.0592)  loss_objectness: 0.0258 (0.0260)  loss_rpn_box_reg: 0.0107 (0.0224)  time: 0.6599  data: 0.0071  max mem: 6504
# Epoch: [12]  [50/60]  eta: 0:00:06  lr: 0.000001  loss: 0.1288 (0.1639)  loss_classifier: 0.0431 (0.0583)  loss_box_reg: 0.0606 (0.0599)  loss_objectness: 0.0209 (0.0249)  loss_rpn_box_reg: 0.0107 (0.0208)  time: 0.6386  data: 0.0067  max mem: 6504
# Epoch: [12]  [59/60]  eta: 0:00:00  lr: 0.000001  loss: 0.1573 (0.1652)  loss_classifier: 0.0563 (0.0575)  loss_box_reg: 0.0572 (0.0599)  loss_objectness: 0.0209 (0.0253)  loss_rpn_box_reg: 0.0139 (0.0226)  time: 0.6189  data: 0.0063  max mem: 6504
# Epoch: [12] Total time: 0:00:39 (0.6518 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:02  model_time: 0.1106 (0.1106)  evaluator_time: 0.0028 (0.0028)  time: 0.6418  data: 0.5273  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1010 (0.1095)  evaluator_time: 0.0026 (0.0022)  time: 0.2482  data: 0.1347  max mem: 6504
# Test: Total time: 0:00:01 (0.2707 s / it)
# Averaged stats: model_time: 0.1010 (0.1095)  evaluator_time: 0.0026 (0.0022)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [13]  [ 0/60]  eta: 0:01:12  lr: 0.000001  loss: 0.0887 (0.0887)  loss_classifier: 0.0416 (0.0416)  loss_box_reg: 0.0161 (0.0161)  loss_objectness: 0.0215 (0.0215)  loss_rpn_box_reg: 0.0096 (0.0096)  time: 1.2079  data: 0.6031  max mem: 6504
# Epoch: [13]  [10/60]  eta: 0:00:34  lr: 0.000001  loss: 0.1555 (0.1446)  loss_classifier: 0.0620 (0.0538)  loss_box_reg: 0.0636 (0.0612)  loss_objectness: 0.0194 (0.0190)  loss_rpn_box_reg: 0.0096 (0.0107)  time: 0.6891  data: 0.0623  max mem: 6504
# Epoch: [13]  [20/60]  eta: 0:00:26  lr: 0.000001  loss: 0.1504 (0.1520)  loss_classifier: 0.0589 (0.0551)  loss_box_reg: 0.0553 (0.0600)  loss_objectness: 0.0194 (0.0216)  loss_rpn_box_reg: 0.0092 (0.0153)  time: 0.6229  data: 0.0054  max mem: 6504
# Epoch: [13]  [30/60]  eta: 0:00:20  lr: 0.000001  loss: 0.1330 (0.1588)  loss_classifier: 0.0443 (0.0568)  loss_box_reg: 0.0517 (0.0618)  loss_objectness: 0.0186 (0.0224)  loss_rpn_box_reg: 0.0062 (0.0178)  time: 0.6628  data: 0.0048  max mem: 6504
# Epoch: [13]  [40/60]  eta: 0:00:13  lr: 0.000001  loss: 0.1498 (0.1530)  loss_classifier: 0.0478 (0.0538)  loss_box_reg: 0.0461 (0.0565)  loss_objectness: 0.0186 (0.0235)  loss_rpn_box_reg: 0.0134 (0.0192)  time: 0.7466  data: 0.0091  max mem: 6504
# Epoch: [13]  [50/60]  eta: 0:00:07  lr: 0.000001  loss: 0.1436 (0.1544)  loss_classifier: 0.0491 (0.0544)  loss_box_reg: 0.0446 (0.0577)  loss_objectness: 0.0226 (0.0234)  loss_rpn_box_reg: 0.0103 (0.0188)  time: 0.7444  data: 0.0153  max mem: 6504
# Epoch: [13]  [59/60]  eta: 0:00:00  lr: 0.000001  loss: 0.1679 (0.1609)  loss_classifier: 0.0625 (0.0565)  loss_box_reg: 0.0490 (0.0602)  loss_objectness: 0.0227 (0.0238)  loss_rpn_box_reg: 0.0097 (0.0204)  time: 0.6987  data: 0.0185  max mem: 6504
# Epoch: [13] Total time: 0:00:42 (0.7055 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:05  model_time: 0.1205 (0.1205)  evaluator_time: 0.0043 (0.0043)  time: 1.3570  data: 1.2293  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1087 (0.1172)  evaluator_time: 0.0043 (0.0039)  time: 0.4426  data: 0.3136  max mem: 6504
# Test: Total time: 0:00:02 (0.5116 s / it)
# Averaged stats: model_time: 0.1087 (0.1172)  evaluator_time: 0.0043 (0.0039)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [14]  [ 0/60]  eta: 0:02:33  lr: 0.000001  loss: 0.2189 (0.2189)  loss_classifier: 0.0782 (0.0782)  loss_box_reg: 0.1119 (0.1119)  loss_objectness: 0.0175 (0.0175)  loss_rpn_box_reg: 0.0113 (0.0113)  time: 2.5634  data: 2.0470  max mem: 6504
# Epoch: [14]  [10/60]  eta: 0:00:39  lr: 0.000001  loss: 0.1883 (0.1895)  loss_classifier: 0.0702 (0.0696)  loss_box_reg: 0.0989 (0.0867)  loss_objectness: 0.0231 (0.0215)  loss_rpn_box_reg: 0.0094 (0.0118)  time: 0.7801  data: 0.1998  max mem: 6504
# Epoch: [14]  [20/60]  eta: 0:00:27  lr: 0.000001  loss: 0.1883 (0.1931)  loss_classifier: 0.0702 (0.0710)  loss_box_reg: 0.0778 (0.0854)  loss_objectness: 0.0224 (0.0223)  loss_rpn_box_reg: 0.0094 (0.0144)  time: 0.5950  data: 0.0118  max mem: 6504
# Epoch: [14]  [30/60]  eta: 0:00:21  lr: 0.000001  loss: 0.1324 (0.1732)  loss_classifier: 0.0557 (0.0630)  loss_box_reg: 0.0466 (0.0717)  loss_objectness: 0.0224 (0.0235)  loss_rpn_box_reg: 0.0099 (0.0149)  time: 0.6996  data: 0.0118  max mem: 6504
# Epoch: [14]  [40/60]  eta: 0:00:14  lr: 0.000001  loss: 0.1130 (0.1615)  loss_classifier: 0.0386 (0.0565)  loss_box_reg: 0.0233 (0.0599)  loss_objectness: 0.0228 (0.0244)  loss_rpn_box_reg: 0.0104 (0.0208)  time: 0.7294  data: 0.0134  max mem: 6504
# Epoch: [14]  [50/60]  eta: 0:00:07  lr: 0.000001  loss: 0.1179 (0.1634)  loss_classifier: 0.0375 (0.0581)  loss_box_reg: 0.0233 (0.0615)  loss_objectness: 0.0224 (0.0243)  loss_rpn_box_reg: 0.0138 (0.0196)  time: 0.6725  data: 0.0133  max mem: 6504
# Epoch: [14]  [59/60]  eta: 0:00:00  lr: 0.000001  loss: 0.1623 (0.1650)  loss_classifier: 0.0595 (0.0589)  loss_box_reg: 0.0597 (0.0621)  loss_objectness: 0.0224 (0.0246)  loss_rpn_box_reg: 0.0104 (0.0194)  time: 0.6727  data: 0.0141  max mem: 6504
# Epoch: [14] Total time: 0:00:42 (0.7001 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:03  model_time: 0.1182 (0.1182)  evaluator_time: 0.0042 (0.0042)  time: 0.7638  data: 0.6397  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1065 (0.1158)  evaluator_time: 0.0038 (0.0034)  time: 0.2868  data: 0.1649  max mem: 6504
# Test: Total time: 0:00:01 (0.3158 s / it)
# Averaged stats: model_time: 0.1065 (0.1158)  evaluator_time: 0.0038 (0.0034)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
# ...
# Epoch: [20]  [10/60]  eta: 0:00:39  lr: 0.000000  loss: 0.1681 (0.1572)  loss_classifier: 0.0576 (0.0559)  loss_box_reg: 0.0422 (0.0555)  loss_objectness: 0.0183 (0.0233)  loss_rpn_box_reg: 0.0134 (0.0225)  time: 0.7852  data: 0.1118  max mem: 6504
# Epoch: [20]  [20/60]  eta: 0:00:29  lr: 0.000000  loss: 0.1681 (0.1706)  loss_classifier: 0.0559 (0.0594)  loss_box_reg: 0.0422 (0.0644)  loss_objectness: 0.0195 (0.0234)  loss_rpn_box_reg: 0.0130 (0.0234)  time: 0.6883  data: 0.0108  max mem: 6504
# Epoch: [20]  [30/60]  eta: 0:00:21  lr: 0.000000  loss: 0.1404 (0.1733)  loss_classifier: 0.0411 (0.0619)  loss_box_reg: 0.0429 (0.0685)  loss_objectness: 0.0192 (0.0223)  loss_rpn_box_reg: 0.0105 (0.0206)  time: 0.6871  data: 0.0084  max mem: 6504
# Epoch: [20]  [40/60]  eta: 0:00:14  lr: 0.000000  loss: 0.1422 (0.1629)  loss_classifier: 0.0516 (0.0582)  loss_box_reg: 0.0429 (0.0629)  loss_objectness: 0.0183 (0.0227)  loss_rpn_box_reg: 0.0088 (0.0191)  time: 0.7256  data: 0.0117  max mem: 6504
# Epoch: [20]  [50/60]  eta: 0:00:07  lr: 0.000000  loss: 0.1422 (0.1573)  loss_classifier: 0.0442 (0.0548)  loss_box_reg: 0.0481 (0.0589)  loss_objectness: 0.0209 (0.0231)  loss_rpn_box_reg: 0.0095 (0.0205)  time: 0.7041  data: 0.0128  max mem: 6504
# Epoch: [20]  [59/60]  eta: 0:00:00  lr: 0.000000  loss: 0.1458 (0.1613)  loss_classifier: 0.0546 (0.0571)  loss_box_reg: 0.0552 (0.0605)  loss_objectness: 0.0209 (0.0233)  loss_rpn_box_reg: 0.0095 (0.0204)  time: 0.6763  data: 0.0125  max mem: 6504
# Epoch: [20] Total time: 0:00:42 (0.7161 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:03  model_time: 0.1260 (0.1260)  evaluator_time: 0.0070 (0.0070)  time: 0.9953  data: 0.8604  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1084 (0.1193)  evaluator_time: 0.0070 (0.0058)  time: 0.3503  data: 0.2223  max mem: 6504
# Test: Total time: 0:00:01 (0.3944 s / it)
# Averaged stats: model_time: 0.1084 (0.1193)  evaluator_time: 0.0070 (0.0058)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [21]  [ 0/60]  eta: 0:01:52  lr: 0.000000  loss: 0.1917 (0.1917)  loss_classifier: 0.0695 (0.0695)  loss_box_reg: 0.0909 (0.0909)  loss_objectness: 0.0144 (0.0144)  loss_rpn_box_reg: 0.0170 (0.0170)  time: 1.8713  data: 1.1184  max mem: 6504
# Epoch: [21]  [10/60]  eta: 0:00:40  lr: 0.000000  loss: 0.1552 (0.1725)  loss_classifier: 0.0443 (0.0577)  loss_box_reg: 0.0506 (0.0570)  loss_objectness: 0.0293 (0.0302)  loss_rpn_box_reg: 0.0131 (0.0277)  time: 0.8090  data: 0.1191  max mem: 6504
# Epoch: [21]  [20/60]  eta: 0:00:30  lr: 0.000000  loss: 0.1552 (0.1761)  loss_classifier: 0.0531 (0.0575)  loss_box_reg: 0.0514 (0.0576)  loss_objectness: 0.0257 (0.0284)  loss_rpn_box_reg: 0.0179 (0.0325)  time: 0.6958  data: 0.0122  max mem: 6504
# Epoch: [21]  [30/60]  eta: 0:00:22  lr: 0.000000  loss: 0.1496 (0.1683)  loss_classifier: 0.0531 (0.0555)  loss_box_reg: 0.0467 (0.0556)  loss_objectness: 0.0220 (0.0269)  loss_rpn_box_reg: 0.0159 (0.0303)  time: 0.7334  data: 0.0097  max mem: 6504
# Epoch: [21]  [40/60]  eta: 0:00:15  lr: 0.000000  loss: 0.1322 (0.1564)  loss_classifier: 0.0403 (0.0524)  loss_box_reg: 0.0396 (0.0512)  loss_objectness: 0.0248 (0.0270)  loss_rpn_box_reg: 0.0094 (0.0258)  time: 0.7682  data: 0.0139  max mem: 6504
# Epoch: [21]  [50/60]  eta: 0:00:07  lr: 0.000000  loss: 0.1477 (0.1586)  loss_classifier: 0.0456 (0.0547)  loss_box_reg: 0.0494 (0.0557)  loss_objectness: 0.0202 (0.0255)  loss_rpn_box_reg: 0.0093 (0.0226)  time: 0.7198  data: 0.0143  max mem: 6504
# Epoch: [21]  [59/60]  eta: 0:00:00  lr: 0.000000  loss: 0.1621 (0.1635)  loss_classifier: 0.0544 (0.0569)  loss_box_reg: 0.0548 (0.0597)  loss_objectness: 0.0182 (0.0249)  loss_rpn_box_reg: 0.0100 (0.0220)  time: 0.6814  data: 0.0125  max mem: 6504
# Epoch: [21] Total time: 0:00:44 (0.7377 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:04  model_time: 0.1203 (0.1203)  evaluator_time: 0.0067 (0.0067)  time: 1.0421  data: 0.9134  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1096 (0.1186)  evaluator_time: 0.0067 (0.0059)  time: 0.3624  data: 0.2345  max mem: 6504
# Test: Total time: 0:00:01 (0.3928 s / it)
# Averaged stats: model_time: 0.1096 (0.1186)  evaluator_time: 0.0067 (0.0059)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [22]  [ 0/60]  eta: 0:02:16  lr: 0.000000  loss: 0.1019 (0.1019)  loss_classifier: 0.0409 (0.0409)  loss_box_reg: 0.0321 (0.0321)  loss_objectness: 0.0124 (0.0124)  loss_rpn_box_reg: 0.0165 (0.0165)  time: 2.2753  data: 1.3059  max mem: 6504
# Epoch: [22]  [10/60]  eta: 0:00:41  lr: 0.000000  loss: 0.1780 (0.1754)  loss_classifier: 0.0522 (0.0506)  loss_box_reg: 0.0442 (0.0495)  loss_objectness: 0.0228 (0.0329)  loss_rpn_box_reg: 0.0165 (0.0424)  time: 0.8397  data: 0.1288  max mem: 6504
# Epoch: [22]  [20/60]  eta: 0:00:30  lr: 0.000000  loss: 0.1799 (0.1845)  loss_classifier: 0.0580 (0.0642)  loss_box_reg: 0.0653 (0.0645)  loss_objectness: 0.0221 (0.0287)  loss_rpn_box_reg: 0.0086 (0.0271)  time: 0.6740  data: 0.0084  max mem: 6504
# Epoch: [22]  [30/60]  eta: 0:00:21  lr: 0.000000  loss: 0.1706 (0.1845)  loss_classifier: 0.0726 (0.0656)  loss_box_reg: 0.0692 (0.0682)  loss_objectness: 0.0217 (0.0283)  loss_rpn_box_reg: 0.0090 (0.0225)  time: 0.6605  data: 0.0069  max mem: 6504
# Epoch: [22]  [40/60]  eta: 0:00:14  lr: 0.000000  loss: 0.1574 (0.1765)  loss_classifier: 0.0507 (0.0616)  loss_box_reg: 0.0589 (0.0655)  loss_objectness: 0.0226 (0.0281)  loss_rpn_box_reg: 0.0090 (0.0214)  time: 0.7070  data: 0.0083  max mem: 6504
# Epoch: [22]  [50/60]  eta: 0:00:07  lr: 0.000000  loss: 0.1316 (0.1677)  loss_classifier: 0.0369 (0.0586)  loss_box_reg: 0.0509 (0.0614)  loss_objectness: 0.0233 (0.0273)  loss_rpn_box_reg: 0.0090 (0.0203)  time: 0.7132  data: 0.0081  max mem: 6504
# Epoch: [22]  [59/60]  eta: 0:00:00  lr: 0.000000  loss: 0.1285 (0.1652)  loss_classifier: 0.0369 (0.0577)  loss_box_reg: 0.0443 (0.0609)  loss_objectness: 0.0220 (0.0269)  loss_rpn_box_reg: 0.0091 (0.0196)  time: 0.6678  data: 0.0073  max mem: 6504
# Epoch: [22] Total time: 0:00:42 (0.7117 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:02  model_time: 0.1123 (0.1123)  evaluator_time: 0.0030 (0.0030)  time: 0.5433  data: 0.4266  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1021 (0.1108)  evaluator_time: 0.0030 (0.0026)  time: 0.2247  data: 0.1097  max mem: 6504
# Test: Total time: 0:00:00 (0.2456 s / it)
# Averaged stats: model_time: 0.1021 (0.1108)  evaluator_time: 0.0030 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [23]  [ 0/60]  eta: 0:01:03  lr: 0.000000  loss: 0.3328 (0.3328)  loss_classifier: 0.0878 (0.0878)  loss_box_reg: 0.1476 (0.1476)  loss_objectness: 0.0260 (0.0260)  loss_rpn_box_reg: 0.0714 (0.0714)  time: 1.0615  data: 0.4556  max mem: 6504
# Epoch: [23]  [10/60]  eta: 0:00:35  lr: 0.000000  loss: 0.1204 (0.1344)  loss_classifier: 0.0419 (0.0421)  loss_box_reg: 0.0444 (0.0491)  loss_objectness: 0.0158 (0.0175)  loss_rpn_box_reg: 0.0224 (0.0257)  time: 0.7016  data: 0.0483  max mem: 6504
# Epoch: [23]  [20/60]  eta: 0:00:26  lr: 0.000000  loss: 0.1351 (0.1633)  loss_classifier: 0.0503 (0.0560)  loss_box_reg: 0.0502 (0.0646)  loss_objectness: 0.0200 (0.0205)  loss_rpn_box_reg: 0.0131 (0.0222)  time: 0.6488  data: 0.0066  max mem: 6504
# Epoch: [23]  [30/60]  eta: 0:00:20  lr: 0.000000  loss: 0.1499 (0.1624)  loss_classifier: 0.0577 (0.0569)  loss_box_reg: 0.0630 (0.0619)  loss_objectness: 0.0267 (0.0245)  loss_rpn_box_reg: 0.0108 (0.0191)  time: 0.6654  data: 0.0061  max mem: 6504
# Epoch: [23]  [40/60]  eta: 0:00:13  lr: 0.000000  loss: 0.1499 (0.1693)  loss_classifier: 0.0577 (0.0594)  loss_box_reg: 0.0630 (0.0650)  loss_objectness: 0.0269 (0.0250)  loss_rpn_box_reg: 0.0102 (0.0199)  time: 0.6653  data: 0.0063  max mem: 6504
# Epoch: [23]  [50/60]  eta: 0:00:06  lr: 0.000000  loss: 0.1534 (0.1707)  loss_classifier: 0.0545 (0.0597)  loss_box_reg: 0.0540 (0.0632)  loss_objectness: 0.0233 (0.0259)  loss_rpn_box_reg: 0.0110 (0.0220)  time: 0.6686  data: 0.0069  max mem: 6504
# Epoch: [23]  [59/60]  eta: 0:00:00  lr: 0.000000  loss: 0.1511 (0.1656)  loss_classifier: 0.0479 (0.0580)  loss_box_reg: 0.0476 (0.0608)  loss_objectness: 0.0181 (0.0253)  loss_rpn_box_reg: 0.0110 (0.0214)  time: 0.7045  data: 0.0084  max mem: 6504
# Epoch: [23] Total time: 0:00:40 (0.6832 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:03  model_time: 0.1318 (0.1318)  evaluator_time: 0.0043 (0.0043)  time: 0.9893  data: 0.8502  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1053 (0.1196)  evaluator_time: 0.0041 (0.0035)  time: 0.3450  data: 0.2178  max mem: 6504
# Test: Total time: 0:00:01 (0.3677 s / it)
# Averaged stats: model_time: 0.1053 (0.1196)  evaluator_time: 0.0041 (0.0035)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060
# Epoch: [24]  [ 0/60]  eta: 0:01:09  lr: 0.000000  loss: 0.2873 (0.2873)  loss_classifier: 0.1162 (0.1162)  loss_box_reg: 0.1226 (0.1226)  loss_objectness: 0.0358 (0.0358)  loss_rpn_box_reg: 0.0127 (0.0127)  time: 1.1522  data: 0.5616  max mem: 6504
# Epoch: [24]  [10/60]  eta: 0:00:34  lr: 0.000000  loss: 0.1338 (0.1498)  loss_classifier: 0.0418 (0.0494)  loss_box_reg: 0.0466 (0.0466)  loss_objectness: 0.0266 (0.0283)  loss_rpn_box_reg: 0.0127 (0.0255)  time: 0.6914  data: 0.0610  max mem: 6504
# Epoch: [24]  [20/60]  eta: 0:00:28  lr: 0.000000  loss: 0.1168 (0.1461)  loss_classifier: 0.0386 (0.0492)  loss_box_reg: 0.0466 (0.0542)  loss_objectness: 0.0204 (0.0236)  loss_rpn_box_reg: 0.0105 (0.0190)  time: 0.7029  data: 0.0072  max mem: 6504
# Epoch: [24]  [30/60]  eta: 0:00:21  lr: 0.000000  loss: 0.1173 (0.1435)  loss_classifier: 0.0378 (0.0486)  loss_box_reg: 0.0425 (0.0520)  loss_objectness: 0.0198 (0.0229)  loss_rpn_box_reg: 0.0080 (0.0200)  time: 0.7435  data: 0.0058  max mem: 6504
# Epoch: [24]  [40/60]  eta: 0:00:14  lr: 0.000000  loss: 0.1219 (0.1469)  loss_classifier: 0.0366 (0.0510)  loss_box_reg: 0.0425 (0.0539)  loss_objectness: 0.0199 (0.0235)  loss_rpn_box_reg: 0.0099 (0.0184)  time: 0.7113  data: 0.0096  max mem: 6504
# Epoch: [24]  [50/60]  eta: 0:00:07  lr: 0.000000  loss: 0.1848 (0.1615)  loss_classifier: 0.0563 (0.0560)  loss_box_reg: 0.0595 (0.0604)  loss_objectness: 0.0199 (0.0236)  loss_rpn_box_reg: 0.0111 (0.0214)  time: 0.6670  data: 0.0108  max mem: 6504
# Epoch: [24]  [59/60]  eta: 0:00:00  lr: 0.000000  loss: 0.1841 (0.1623)  loss_classifier: 0.0622 (0.0571)  loss_box_reg: 0.0609 (0.0609)  loss_objectness: 0.0207 (0.0235)  loss_rpn_box_reg: 0.0111 (0.0207)  time: 0.6471  data: 0.0104  max mem: 6504
# Epoch: [24] Total time: 0:00:41 (0.6987 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:02  model_time: 0.1166 (0.1166)  evaluator_time: 0.0036 (0.0036)  time: 0.6089  data: 0.4874  max mem: 6504
# Test:  [3/4]  eta: 0:00:00  model_time: 0.1058 (0.1145)  evaluator_time: 0.0036 (0.0031)  time: 0.2456  data: 0.1258  max mem: 6504
# Test: Total time: 0:00:01 (0.2714 s / it)
# Averaged stats: model_time: 0.1058 (0.1145)  evaluator_time: 0.0036 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.060

# %%
# set to evaluation mode
torch.save(model, 'faster-rcnn-hand-25epoch_.pt')
model.eval()
CLASS_NAMES = ['__background__', 'hand']
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#   )
# )

# %%
torch.load('faster-rcnn-hand-100epoch.pt')
model.eval()
CLASS_NAMES = ['__background__', 'hand']
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#   )
# )

# %%
# %matplotlib inline
from PIL import Image
import matplotlib.pyplot as plt
import torch
import torchvision.transforms as T
import torchvision
import numpy as np

import cv2
import random
import warnings
warnings.filterwarnings('ignore')


def get_prediction(img_path, confidence):
  """
  get_prediction
    parameters:
      - img_path - path of the input image
      - confidence - threshold value for prediction score
    method:
      - Image is obtained from the image path
      - the image is converted to image tensor using PyTorch's Transforms
      - image is passed through the model to get the predictions
      - class, box coordinates are obtained, but only prediction score > threshold
        are chosen.
    
  """
  img = Image.open(img_path)
  transform = T.Compose([T.ToTensor()])
  img = transform(img).to(device)
  pred = model([img])
  pred_class = [CLASS_NAMES[i] for i in list(pred[0]['labels'].cpu().numpy())]
  pred_boxes = [[(i[0], i[1]), (i[2], i[3])] for i in list(pred[0]['boxes'].detach().cpu().numpy())]
  pred_score = list(pred[0]['scores'].detach().cpu().numpy())
  print(np.max(pred_score))
  try:
        pred_t = [pred_score.index(x) for x in pred_score if x>confidence][-1]
  except IndexError:
    pred_t = [pred_score.index(x) for x in pred_score if x>=np.max(pred_score)][-1]

  pred_boxes = pred_boxes[:pred_t+1]
  pred_class = pred_class[:pred_t+1]
  pred_score = pred_score[:pred_t+1]
  return pred_boxes, pred_class, pred_score

def detect_object(img_path, confidence=0.5, rect_th=2, text_size=0.5, text_th=1):
  """
  object_detection_api
    parameters:
      - img_path - path of the input image
      - confidence - threshold value for prediction score
      - rect_th - thickness of bounding box
      - text_size - size of the class label text
      - text_th - thichness of the text
    method:
      - prediction is obtained from get_prediction method
      - for each prediction, bounding box is drawn and text is written 
        with opencv
      - the final image is displayed
  """
  boxes, pred_cls, pred_score = get_prediction(img_path, confidence)
  img = cv2.imread(img_path)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  # print(len(boxes))
  for i in range(len(boxes)):
    cv2.rectangle(img, (int(boxes[i][0][0]),int(boxes[i][0][1])), (int(boxes[i][1][0]),int(boxes[i][1][1])), color=(0, 255, 0), thickness=rect_th)
    cv2.putText(img,pred_cls[i]+": "+str(round(pred_score[i],3)), (int(boxes[i][0][0]),int(boxes[i][0][1])), cv2.FONT_HERSHEY_SIMPLEX, text_size, (0,255,0),thickness=text_th)
  plt.figure(figsize=(6,6))
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])
  plt.show()

# %%
val_dir = 'hand/val' 
for element in os.listdir(val_dir):
    if element[-3:]=='jpg':
        detect_object(os.path.join(val_dir,element),confidence=0.9)
#detect_object('hand/val/6.jpg', confidence=0.3)
# Out:
# 0.09780137
# 0.30293876
# 0.1556103
# 0.3398795

# %% [markdown]
# based on this : https://haochen23.github.io/2020/06/fine-tune-faster-rcnn-pytorch.html
